# %%
# Importing Libraries
# !pip install ta
# !pip install yfinance
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from datetime import timedelta
from sklearn.preprocessing import RobustScaler
plt.style.use("bmh")

# Technical Analysis library
import ta

# Neural Network library
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

#stock
import yfinance as yf
df = yf.download("NVDC34.SA", start="2015-01-01", end="2022-08-18", interval = '1d', auto_adjust = True, prepost = False)
df = df.reset_index()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ta in /usr/local/lib/python3.7/dist-packages (0.10.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2022.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.85)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.9.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.28.1)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.1.1)
# [*********************100%***********************]  1 of 1 completed

# %%
## Datetime conversion
df['Date'] = pd.to_datetime(df.Date)

# Setting the index
df.set_index('Date', inplace=True)

# Dropping any NaNs
df.dropna(inplace=True)



## Technical Indicators

# Adding all the indicators
df = ta.add_all_ta_features(df, open="Open", high="High", low="Low", close="Close", volume="Volume", fillna=True)

# Dropping everything else besides 'Close' and the Indicators
df.drop(['Open', 'High', 'Low', 'Volume'], axis=1, inplace=True)


# Only using the last 1000 days of data to get a more accurate representation of the current market climate
df = df.tail(1000)



## Scaling

# Scale fitting the close prices separately for inverse_transformations purposes later
close_scaler = RobustScaler()

close_scaler.fit(df[['Close']])

# Normalizing/Scaling the DF
scaler = RobustScaler()

df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns, index=df.index)
# Out:
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:780: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:785: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)

# %%
def split_sequence(seq, n_steps_in, n_steps_out):
    """
    Splits the multivariate time sequence
    """
    
    # Creating a list for both variables
    X, y = [], []
    
    for i in range(len(seq)):
        
        # Finding the end of the current sequence
        end = i + n_steps_in
        out_end = end + n_steps_out
        
        # Breaking out of the loop if we have exceeded the dataset's length
        if out_end > len(seq):
            break
        
        # Splitting the sequences into: x = past prices and indicators, y = prices ahead
        seq_x, seq_y = seq[i:end, :], seq[end:out_end, 0]
        
        X.append(seq_x)
        y.append(seq_y)
    
    return np.array(X), np.array(y)
  
  
def visualize_training_results(results):
    """
    Plots the loss and accuracy for the training and testing data
    """
    history = results.history
    plt.figure(figsize=(16,5))
    plt.plot(history['val_loss'])
    plt.plot(history['loss'])
    plt.legend(['val_loss', 'loss'])
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()
    
    plt.figure(figsize=(16,5))
    plt.plot(history['val_accuracy'])
    plt.plot(history['accuracy'])
    plt.legend(['val_accuracy', 'accuracy'])
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()
    
    
def layer_maker(n_layers, n_nodes, activation, drop=None, d_rate=.5):
    """
    Creates a specified number of hidden layers for an RNN
    Optional: Adds regularization option - the dropout layer to prevent potential overfitting (if necessary)
    """
    
    # Creating the specified number of hidden layers with the specified number of nodes
    for x in range(1,n_layers+1):
        model.add(LSTM(n_nodes, activation=activation, return_sequences=True))

        # Adds a Dropout layer after every Nth hidden layer (the 'drop' variable)
        try:
            if x % drop == 0:
                model.add(Dropout(d_rate))
        except:
            pass
          
          
def validater(n_per_in, n_per_out):
    """
    Runs a 'For' loop to iterate through the length of the DF and create predicted values for every stated interval
    Returns a DF containing the predicted values for the model with the corresponding index values based on a business day frequency
    """
    
    # Creating an empty DF to store the predictions
    predictions = pd.DataFrame(index=df.index, columns=[df.columns[0]])

    for i in range(n_per_in, len(df)-n_per_in, n_per_out):
        # Creating rolling intervals to predict off of
        x = df[-i - n_per_in:-i]

        # Predicting using rolling intervals
        yhat = model.predict(np.array(x).reshape(1, n_per_in, n_features))

        # Transforming values back to their normal prices
        yhat = close_scaler.inverse_transform(yhat)[0]

        # DF to store the values and append later, frequency uses business days
        pred_df = pd.DataFrame(yhat, 
                               index=pd.date_range(start=x.index[-1], 
                                                   periods=len(yhat), 
                                                   freq="B"),
                               columns=[x.columns[0]])

        # Updating the predictions DF
        predictions.update(pred_df)
        
    return predictions


def val_rmse(df1, df2):
    """
    Calculates the root mean square error between the two Dataframes
    """
    df = df1.copy()
    
    # Adding a new column with the closing prices from the second DF
    df['close2'] = df2.Close
    
    # Dropping the NaN values
    df.dropna(inplace=True)
    
    # Adding another column containing the difference between the two DFs' closing prices
    df['diff'] = df.Close - df.close2
    
    # Squaring the difference and getting the mean
    rms = (df[['diff']]**2).mean()
    
    # Returning the sqaure root of the root mean square
    return float(np.sqrt(rms))

# %%
# How many periods looking back to learn
n_per_in  = 180
# How many periods to predict
n_per_out = 30
# Features 
n_features = df.shape[1]
# Splitting the data into appropriate sequences
X, y = split_sequence(df.to_numpy(), n_per_in, n_per_out)

# %%
## Creating the NN

# Instatiating the model
model = Sequential()

# Activation
activ = "tanh"

# Input layer
model.add(LSTM(180, 
               activation=activ, 
               return_sequences=True, 
               input_shape=(n_per_in, n_features)))

# Hidden layers
layer_maker(n_layers=1, 
            n_nodes=30, 
            activation=activ)

# Final Hidden layer
model.add(LSTM(60, activation=activ))

# Output layer
model.add(Dense(n_per_out))

# Model summary
model.summary()

# Compiling the data with selected specifications
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

## Fitting and Training
res = model.fit(X, y, epochs=75, batch_size=32, validation_split=0.1)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 100, 100)          75200
#
#  lstm_7 (LSTM)               (None, 100, 30)           15720
#
#  lstm_8 (LSTM)               (None, 60)                21840
#
#  dense_2 (Dense)             (None, 30)                1830
#
# =================================================================
# Total params: 114,590
# Trainable params: 114,590
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 20/20 [==============================] - 18s 517ms/step - loss: 0.2093 - accuracy: 0.0423 - val_loss: 0.1751 - val_accuracy: 0.0290
# Epoch 2/100
# 20/20 [==============================] - 8s 379ms/step - loss: 0.0505 - accuracy: 0.0602 - val_loss: 0.1155 - val_accuracy: 0.0145
# Epoch 3/100
# 20/20 [==============================] - 6s 303ms/step - loss: 0.0213 - accuracy: 0.0683 - val_loss: 0.1465 - val_accuracy: 0.0145
# Epoch 4/100
# 20/20 [==============================] - 4s 183ms/step - loss: 0.0124 - accuracy: 0.0829 - val_loss: 0.1500 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 20/20 [==============================] - 4s 177ms/step - loss: 0.0090 - accuracy: 0.0959 - val_loss: 0.1692 - val_accuracy: 0.0290
# Epoch 6/100
# 20/20 [==============================] - 4s 182ms/step - loss: 0.0070 - accuracy: 0.1171 - val_loss: 0.1429 - val_accuracy: 0.0435
# Epoch 7/100
# 20/20 [==============================] - 4s 181ms/step - loss: 0.0058 - accuracy: 0.1203 - val_loss: 0.1348 - val_accuracy: 0.0290
# Epoch 8/100
# 20/20 [==============================] - 4s 180ms/step - loss: 0.0049 - accuracy: 0.1317 - val_loss: 0.1334 - val_accuracy: 0.0580
# Epoch 9/100
# 20/20 [==============================] - 4s 182ms/step - loss: 0.0043 - accuracy: 0.1220 - val_loss: 0.1275 - val_accuracy: 0.0580
# Epoch 10/100
# 20/20 [==============================] - 4s 178ms/step - loss: 0.0038 - accuracy: 0.1285 - val_loss: 0.1487 - val_accuracy: 0.1159
# Epoch 11/100
# 20/20 [==============================] - 4s 186ms/step - loss: 0.0034 - accuracy: 0.1382 - val_loss: 0.1329 - val_accuracy: 0.0870
# Epoch 12/100
# 20/20 [==============================] - 4s 178ms/step - loss: 0.0031 - accuracy: 0.1431 - val_loss: 0.1442 - val_accuracy: 0.1014
# Epoch 13/100
# 20/20 [==============================] - 4s 180ms/step - loss: 0.0030 - accuracy: 0.1398 - val_loss: 0.1322 - val_accuracy: 0.1159
# Epoch 14/100
# 20/20 [==============================] - 4s 179ms/step - loss: 0.0028 - accuracy: 0.1659 - val_loss: 0.1255 - val_accuracy: 0.1014
# Epoch 15/100
# 20/20 [==============================] - 4s 181ms/step - loss: 0.0026 - accuracy: 0.1577 - val_loss: 0.1350 - val_accuracy: 0.0870
# Epoch 16/100
# 20/20 [==============================] - 4s 181ms/step - loss: 0.0025 - accuracy: 0.1805 - val_loss: 0.1269 - val_accuracy: 0.1014
# Epoch 17/100
# 20/20 [==============================] - 4s 180ms/step - loss: 0.0024 - accuracy: 0.1772 - val_loss: 0.1407 - val_accuracy: 0.1304
# Epoch 18/100
# 20/20 [==============================] - 4s 178ms/step - loss: 0.0023 - accuracy: 0.1967 - val_loss: 0.1281 - val_accuracy: 0.0870
# Epoch 19/100
# 20/20 [==============================] - 4s 179ms/step - loss: 0.0023 - accuracy: 0.2000 - val_loss: 0.1278 - val_accuracy: 0.0870
# Epoch 20/100
# 20/20 [==============================] - 4s 178ms/step - loss: 0.0022 - accuracy: 0.1886 - val_loss: 0.1419 - val_accuracy: 0.0435
# Epoch 21/100
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0022 - accuracy: 0.2033 - val_loss: 0.1284 - val_accuracy: 0.0870
# Epoch 22/100
# 20/20 [==============================] - 4s 181ms/step - loss: 0.0022 - accuracy: 0.1967 - val_loss: 0.1270 - val_accuracy: 0.0725
# Epoch 23/100
# 20/20 [==============================] - 4s 184ms/step - loss: 0.0021 - accuracy: 0.2098 - val_loss: 0.1266 - val_accuracy: 0.0725
# Epoch 24/100
# 20/20 [==============================] - 4s 178ms/step - loss: 0.0022 - accuracy: 0.2146 - val_loss: 0.1214 - val_accuracy: 0.1159
# Epoch 25/100
# 20/20 [==============================] - 4s 183ms/step - loss: 0.0021 - accuracy: 0.2195 - val_loss: 0.1483 - val_accuracy: 0.1014
# Epoch 26/100
# 20/20 [==============================] - 4s 182ms/step - loss: 0.0021 - accuracy: 0.2163 - val_loss: 0.1296 - val_accuracy: 0.0870
# Epoch 27/100
# 20/20 [==============================] - 4s 182ms/step - loss: 0.0020 - accuracy: 0.2033 - val_loss: 0.1329 - val_accuracy: 0.0725
# Epoch 28/100
# 20/20 [==============================] - 4s 181ms/step - loss: 0.0018 - accuracy: 0.2211 - val_loss: 0.1254 - val_accuracy: 0.1014
# Epoch 29/100
# 20/20 [==============================] - 4s 220ms/step - loss: 0.0018 - accuracy: 0.2081 - val_loss: 0.1297 - val_accuracy: 0.0870
# Epoch 30/100
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0018 - accuracy: 0.2244 - val_loss: 0.1326 - val_accuracy: 0.1159
# Epoch 31/100
# 20/20 [==============================] - 4s 185ms/step - loss: 0.0019 - accuracy: 0.2228 - val_loss: 0.1316 - val_accuracy: 0.1014
# Epoch 32/100
# 20/20 [==============================] - 4s 182ms/step - loss: 0.0018 - accuracy: 0.2163 - val_loss: 0.1236 - val_accuracy: 0.0725
# Epoch 33/100
# 20/20 [==============================] - 4s 183ms/step - loss: 0.0018 - accuracy: 0.2130 - val_loss: 0.1278 - val_accuracy: 0.1014
# Epoch 34/100
# 20/20 [==============================] - 4s 181ms/step - loss: 0.0019 - accuracy: 0.2423 - val_loss: 0.1346 - val_accuracy: 0.0870
# Epoch 35/100
# 20/20 [==============================] - 4s 183ms/step - loss: 0.0017 - accuracy: 0.2228 - val_loss: 0.1272 - val_accuracy: 0.1014
# Epoch 36/100
# 20/20 [==============================] - 4s 183ms/step - loss: 0.0017 - accuracy: 0.2325 - val_loss: 0.1237 - val_accuracy: 0.1159
# Epoch 37/100
# 20/20 [==============================] - 4s 180ms/step - loss: 0.0018 - accuracy: 0.2276 - val_loss: 0.1332 - val_accuracy: 0.1159
# Epoch 38/100
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0017 - accuracy: 0.2293 - val_loss: 0.1274 - val_accuracy: 0.1159
# Epoch 39/100
# 20/20 [==============================] - 4s 180ms/step - loss: 0.0017 - accuracy: 0.2260 - val_loss: 0.1327 - val_accuracy: 0.0580
# Epoch 40/100
# 20/20 [==============================] - 4s 182ms/step - loss: 0.0017 - accuracy: 0.2163 - val_loss: 0.1391 - val_accuracy: 0.0580
# Epoch 41/100
# 20/20 [==============================] - 4s 181ms/step - loss: 0.0016 - accuracy: 0.2260 - val_loss: 0.1306 - val_accuracy: 0.0870
# Epoch 42/100
# 20/20 [==============================] - 4s 181ms/step - loss: 0.0017 - accuracy: 0.2260 - val_loss: 0.1299 - val_accuracy: 0.1304
# Epoch 43/100
# 20/20 [==============================] - 4s 180ms/step - loss: 0.0016 - accuracy: 0.2309 - val_loss: 0.1318 - val_accuracy: 0.1304
# Epoch 44/100
# 20/20 [==============================] - 4s 178ms/step - loss: 0.0016 - accuracy: 0.2309 - val_loss: 0.1275 - val_accuracy: 0.1014
# Epoch 45/100
# 20/20 [==============================] - 4s 180ms/step - loss: 0.0017 - accuracy: 0.2195 - val_loss: 0.1396 - val_accuracy: 0.1159
# Epoch 46/100
# 20/20 [==============================] - 4s 184ms/step - loss: 0.0020 - accuracy: 0.2098 - val_loss: 0.1173 - val_accuracy: 0.1159
# Epoch 47/100
# 20/20 [==============================] - 4s 181ms/step - loss: 0.0019 - accuracy: 0.2211 - val_loss: 0.1311 - val_accuracy: 0.1014
# Epoch 48/100
# 20/20 [==============================] - 4s 181ms/step - loss: 0.0017 - accuracy: 0.2130 - val_loss: 0.1124 - val_accuracy: 0.1304
# Epoch 49/100
# 20/20 [==============================] - 4s 184ms/step - loss: 0.0018 - accuracy: 0.2228 - val_loss: 0.1141 - val_accuracy: 0.1304
# Epoch 50/100
# 20/20 [==============================] - 4s 181ms/step - loss: 0.0018 - accuracy: 0.2260 - val_loss: 0.1320 - val_accuracy: 0.1159
# Epoch 51/100
# 20/20 [==============================] - 4s 180ms/step - loss: 0.0017 - accuracy: 0.2146 - val_loss: 0.1130 - val_accuracy: 0.1304
# Epoch 52/100
# 20/20 [==============================] - 4s 185ms/step - loss: 0.0017 - accuracy: 0.2130 - val_loss: 0.1207 - val_accuracy: 0.1159
# Epoch 53/100
# 20/20 [==============================] - 4s 183ms/step - loss: 0.0016 - accuracy: 0.2325 - val_loss: 0.1286 - val_accuracy: 0.1159
# Epoch 54/100
# 20/20 [==============================] - 4s 180ms/step - loss: 0.0016 - accuracy: 0.2276 - val_loss: 0.1368 - val_accuracy: 0.1159
# Epoch 55/100
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0016 - accuracy: 0.2455 - val_loss: 0.1265 - val_accuracy: 0.1159
# Epoch 56/100
# 20/20 [==============================] - 4s 184ms/step - loss: 0.0016 - accuracy: 0.2341 - val_loss: 0.1258 - val_accuracy: 0.1159
# Epoch 57/100
# 20/20 [==============================] - 4s 185ms/step - loss: 0.0015 - accuracy: 0.2585 - val_loss: 0.1215 - val_accuracy: 0.1159
# Epoch 58/100
# 20/20 [==============================] - 4s 182ms/step - loss: 0.0015 - accuracy: 0.2098 - val_loss: 0.1242 - val_accuracy: 0.1159
# Epoch 59/100
# 20/20 [==============================] - 4s 183ms/step - loss: 0.0016 - accuracy: 0.2163 - val_loss: 0.1182 - val_accuracy: 0.1304
# Epoch 60/100
# 20/20 [==============================] - 4s 181ms/step - loss: 0.0015 - accuracy: 0.2195 - val_loss: 0.1173 - val_accuracy: 0.1304
# Epoch 61/100
# 20/20 [==============================] - 4s 180ms/step - loss: 0.0015 - accuracy: 0.2341 - val_loss: 0.1223 - val_accuracy: 0.1159
# Epoch 62/100
# 20/20 [==============================] - 4s 182ms/step - loss: 0.0015 - accuracy: 0.2374 - val_loss: 0.1178 - val_accuracy: 0.1014
# Epoch 63/100
# 20/20 [==============================] - 4s 182ms/step - loss: 0.0015 - accuracy: 0.2374 - val_loss: 0.1211 - val_accuracy: 0.0580
# Epoch 64/100
# 20/20 [==============================] - 4s 184ms/step - loss: 0.0015 - accuracy: 0.2358 - val_loss: 0.1257 - val_accuracy: 0.1014
# Epoch 65/100
# 20/20 [==============================] - 4s 184ms/step - loss: 0.0014 - accuracy: 0.2390 - val_loss: 0.1185 - val_accuracy: 0.0725
# Epoch 66/100
# 20/20 [==============================] - 4s 182ms/step - loss: 0.0014 - accuracy: 0.2195 - val_loss: 0.1171 - val_accuracy: 0.0870
# Epoch 67/100
# 20/20 [==============================] - 4s 181ms/step - loss: 0.0015 - accuracy: 0.2504 - val_loss: 0.1257 - val_accuracy: 0.0580
# Epoch 68/100
# 20/20 [==============================] - 4s 182ms/step - loss: 0.0014 - accuracy: 0.2423 - val_loss: 0.1182 - val_accuracy: 0.1159
# Epoch 69/100
# 20/20 [==============================] - 4s 181ms/step - loss: 0.0015 - accuracy: 0.2488 - val_loss: 0.1222 - val_accuracy: 0.1014
# Epoch 70/100
# 20/20 [==============================] - 4s 182ms/step - loss: 0.0014 - accuracy: 0.2276 - val_loss: 0.1134 - val_accuracy: 0.0870
# Epoch 71/100
# 20/20 [==============================] - 4s 184ms/step - loss: 0.0015 - accuracy: 0.2341 - val_loss: 0.1149 - val_accuracy: 0.0725
# Epoch 72/100
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0015 - accuracy: 0.2455 - val_loss: 0.1171 - val_accuracy: 0.1159
# Epoch 73/100
# 20/20 [==============================] - 4s 214ms/step - loss: 0.0015 - accuracy: 0.2244 - val_loss: 0.1206 - val_accuracy: 0.1449
# Epoch 74/100
# 20/20 [==============================] - 4s 182ms/step - loss: 0.0014 - accuracy: 0.2276 - val_loss: 0.1170 - val_accuracy: 0.1014
# Epoch 75/100
# 20/20 [==============================] - 4s 182ms/step - loss: 0.0014 - accuracy: 0.2309 - val_loss: 0.1181 - val_accuracy: 0.1159
# Epoch 76/100
# 20/20 [==============================] - 4s 184ms/step - loss: 0.0014 - accuracy: 0.2341 - val_loss: 0.1202 - val_accuracy: 0.0725
# Epoch 77/100
# 20/20 [==============================] - 4s 180ms/step - loss: 0.0014 - accuracy: 0.2618 - val_loss: 0.1126 - val_accuracy: 0.0580
# Epoch 78/100
# 20/20 [==============================] - 4s 180ms/step - loss: 0.0014 - accuracy: 0.2553 - val_loss: 0.1220 - val_accuracy: 0.0725
# Epoch 79/100
# 20/20 [==============================] - 4s 182ms/step - loss: 0.0014 - accuracy: 0.2439 - val_loss: 0.1105 - val_accuracy: 0.1014
# Epoch 80/100
# 20/20 [==============================] - 4s 183ms/step - loss: 0.0014 - accuracy: 0.2358 - val_loss: 0.1130 - val_accuracy: 0.1014
# Epoch 81/100
# 20/20 [==============================] - 4s 185ms/step - loss: 0.0014 - accuracy: 0.2407 - val_loss: 0.1234 - val_accuracy: 0.0580
# Epoch 82/100
# 20/20 [==============================] - 4s 183ms/step - loss: 0.0013 - accuracy: 0.2780 - val_loss: 0.1141 - val_accuracy: 0.1304
# Epoch 83/100
# 20/20 [==============================] - 4s 183ms/step - loss: 0.0013 - accuracy: 0.2585 - val_loss: 0.1112 - val_accuracy: 0.1159
# Epoch 84/100
# 20/20 [==============================] - 4s 181ms/step - loss: 0.0013 - accuracy: 0.2520 - val_loss: 0.1160 - val_accuracy: 0.0580
# Epoch 85/100
# 20/20 [==============================] - 4s 185ms/step - loss: 0.0013 - accuracy: 0.2732 - val_loss: 0.1104 - val_accuracy: 0.0290
# Epoch 86/100
# 20/20 [==============================] - 4s 187ms/step - loss: 0.0013 - accuracy: 0.2602 - val_loss: 0.1109 - val_accuracy: 0.1159
# Epoch 87/100
# 20/20 [==============================] - 4s 181ms/step - loss: 0.0014 - accuracy: 0.2504 - val_loss: 0.1180 - val_accuracy: 0.0435
# Epoch 88/100
# 20/20 [==============================] - 4s 182ms/step - loss: 0.0016 - accuracy: 0.2439 - val_loss: 0.1157 - val_accuracy: 0.0580
# Epoch 89/100
# 20/20 [==============================] - 4s 188ms/step - loss: 0.0018 - accuracy: 0.2455 - val_loss: 0.1264 - val_accuracy: 0.0870
# Epoch 90/100
# 20/20 [==============================] - 5s 231ms/step - loss: 0.0015 - accuracy: 0.2634 - val_loss: 0.1125 - val_accuracy: 0.0725
# Epoch 91/100
# 20/20 [==============================] - 4s 183ms/step - loss: 0.0013 - accuracy: 0.2537 - val_loss: 0.1130 - val_accuracy: 0.1304
# Epoch 92/100
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0013 - accuracy: 0.2504 - val_loss: 0.1189 - val_accuracy: 0.0725
# Epoch 93/100
# 20/20 [==============================] - 4s 182ms/step - loss: 0.0013 - accuracy: 0.2618 - val_loss: 0.1214 - val_accuracy: 0.0870
# Epoch 94/100
# 20/20 [==============================] - 4s 182ms/step - loss: 0.0013 - accuracy: 0.2585 - val_loss: 0.1160 - val_accuracy: 0.0290
# Epoch 95/100
# 20/20 [==============================] - 4s 179ms/step - loss: 0.0013 - accuracy: 0.2585 - val_loss: 0.1085 - val_accuracy: 0.0290
# Epoch 96/100
# 20/20 [==============================] - 4s 186ms/step - loss: 0.0012 - accuracy: 0.2797 - val_loss: 0.1109 - val_accuracy: 0.0435
# Epoch 97/100
# 20/20 [==============================] - 4s 185ms/step - loss: 0.0012 - accuracy: 0.2585 - val_loss: 0.1105 - val_accuracy: 0.0870
# Epoch 98/100
# 20/20 [==============================] - 4s 184ms/step - loss: 0.0013 - accuracy: 0.2634 - val_loss: 0.1109 - val_accuracy: 0.0290
# Epoch 99/100
# 20/20 [==============================] - 4s 184ms/step - loss: 0.0012 - accuracy: 0.2699 - val_loss: 0.1175 - val_accuracy: 0.0725
# Epoch 100/100
# 20/20 [==============================] - 4s 180ms/step - loss: 0.0012 - accuracy: 0.2715 - val_loss: 0.1190 - val_accuracy: 0.0725

# %%
visualize_training_results(res)

# %%
# Transforming the actual values to their original price
actual = pd.DataFrame(close_scaler.inverse_transform(df[["Close"]]), 
                      index=df.index, 
                      columns=[df.columns[0]])

# Getting a DF of the predicted values to validate against
predictions = validater(n_per_in, n_per_out)

# Printing the RMSE
print("RMSE:", val_rmse(actual, predictions))
    
# Plotting
plt.figure(figsize=(16,6))

# Plotting those predictions
plt.plot(predictions, label='Predicted')

# Plotting the actual values
plt.plot(actual, label='Actual')

plt.title(f"Predicted vs Actual Closing Prices")
plt.ylabel("Price")
plt.legend()
#plt.xlim('2018-05-01', '2020-05-01')
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# RMSE: 0.6604043558135488

# %%
# Predicting off of the most recent days from the original DF
yhat = model.predict(np.array(df.tail(n_per_in)).reshape(1, n_per_in, n_features))

# Transforming the predicted values back to their original format
yhat = close_scaler.inverse_transform(yhat)[0]

# Creating a DF of the predicted prices
preds = pd.DataFrame(yhat, 
                     index=pd.date_range(start=df.index[-1]+timedelta(days=1), 
                                         periods=len(yhat), 
                                         freq="B"), 
                     columns=[df.columns[0]])

# Number of periods back to plot the actual values
pers = n_per_in

# Transforming the actual values to their original price
actual = pd.DataFrame(close_scaler.inverse_transform(df[["Close"]].tail(pers)), 
                      index=df.Close.tail(pers).index, 
                      columns=[df.columns[0]]).append(preds.head(1))

# Printing the predicted prices
print(preds)

# Plotting
plt.figure(figsize=(16,6))
plt.plot(actual, label="Actual Prices")
plt.plot(preds, label="Predicted Prices")
plt.ylabel("Price")
plt.xlabel("Dates")
plt.title(f"Forecasting the next {len(yhat)} days")
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 34ms/step
#                 Close
# 2022-08-18  20.576065
# 2022-08-19  20.242540
# 2022-08-22  20.778515
# 2022-08-23  20.931801
# 2022-08-24  20.455435
# 2022-08-25  21.301182
# 2022-08-26  21.556921
# 2022-08-29  21.798220
# 2022-08-30  21.713545
# 2022-08-31  22.333656
# 2022-09-01  21.297258
# 2022-09-02  22.009970
# 2022-09-05  21.836851
# 2022-09-06  20.669712
# 2022-09-07  20.529823
# 2022-09-08  20.555618
# 2022-09-09  20.303970
# 2022-09-12  20.481421
# 2022-09-13  20.622963
# 2022-09-14  20.863340
# 2022-09-15  20.557457
# 2022-09-16  21.215443
# 2022-09-19  21.396114
# 2022-09-20  21.797611
# 2022-09-21  22.662960
# 2022-09-22  22.212448
# 2022-09-23  22.931040
# 2022-09-26  22.416237
# 2022-09-27  22.306732
# 2022-09-28  22.342726
